# %%
from plotting import plot

# %%
# !ls results
# Out:
# xp_rexnet100	    xp_rexnet150_part2	 xp_test   xpd6
# xp_rexnet100_part2  xp_rexnetr300	 xp_test2  xpd7
# xp_rexnet150	    xp_rexnetr300_part2  xp_test3  xptest1

# %%
plot("xp_rexnet100")

# %%
plot("xp_rexnet100_part2")

# %%
plot("xp_rexnet150")

# %%
plot("xp_rexnet150_part2")

# %%
plot("xp_rexnetr300")

# %%
plot("xp_rexnetr300_part2")
